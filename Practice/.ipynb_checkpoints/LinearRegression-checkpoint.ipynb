# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
from scipy import stats
slope,intercept,r,p,std_err=stats.linregress(x,y)

print("Slope:",slope)
print("Intercept:",intercept)
print("Relationship:",r)
print("p:",p)
print("Error:",std_err)
# Out:
# Slope: -1.7512877115526118
# Intercept: 103.10596026490066
# Relationship: -0.758591524376155
# p: 0.002646873922456106
# Error: 0.453536157607742

# %% [markdown]
# Slope is -ve => Decreasing <br>
# Relationship is good not very good.

# %%
def draw(x):
    return slope * x + intercept

model = list(map(draw,x))
print("Model:",model)

plt.plot(x,model,color='y')
plt.scatter(x,y)
# Out:
# Model: [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
print("Mean Absolute Error:",mean_absolute_error(y,model))
print("Mean Squared Error:",mean_squared_error(y,model))
print("r2_score:",r2_score(y,model))
print("r2_score percentage:",r2_score(y,model)*100,"%")
# Out:
# Mean Absolute Error: 4.939944529348507
# Mean Squared Error: 36.38976623082586
# r2_score: 0.5754611008553381
# r2_score percentage: 57.54611008553381 %

# %% [markdown]
# # Let's make prediction

# %%
# Let's consider a point for x=10 and predict y
a=10
b=draw(a)
print("Predicted value for a:",b)
# Out:
# Predicted value for a: 85.59308314937454

# %%
# Let's plot
plt.scatter(x,y)
plt.plot(x,model,color='y')
plt.scatter(a,b,color='r') # predicted value in red dot

# %% [markdown]
# # Bad Fit

# %%
# from this example we will understand the bad fit
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope,intercept,r,p,std_err=stats.linregress(x,y)
print("Slope:",slope)
print("Intercept:",intercept)
print("Relationship:",r)
print("p:",p)
print("Error:",std_err)
# Out:
# Slope: 0.01391658139845263
# Intercept: 40.452282828936454
# Relationship: 0.01331814154297491
# p: 0.955558800440106
# Error: 0.24627150586388075

# %% [markdown]
# The closer the Relationship 'r' to 0 the more bad relationship exists. <br>
# Let's visualize

# %%
def fun(x):
    return slope*x + intercept
model=list(map(fun,x))
plt.scatter(x,y)
plt.plot(x,model)

# %% [markdown]
# From above the bad fit can be easily visualized

# %%
print("Mean Absolute Error:",mean_absolute_error(y,model))
print("Mean Squared Error:",mean_squared_error(y,model))
print("r2_score:",r2_score(y,model))
print("r2_score percentage:",r2_score(y,model)*100,"%")
# Out:
# Mean Absolute Error: 21.37783255614558
# Mean Squared Error: 674.8277826085198
# r2_score: 0.000177372894158756
# r2_score percentage: 0.0177372894158756 %

# %%
# This is a bad fit as error is too high due to which score is too less.
