# %%
# Reading the dataset
import pandas as pd
df=pd.read_csv('../Datasets/car data/car data.csv')
df #Dataframe
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Dataset Head
df.head()
# Provides with top 5 rows
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# shape provides the dimension of dataset
df.shape
# Out:
# (301, 9)

# %%
# Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# No missing values found.

# %%
# Encoding the Categorical Data
from sklearn.preprocessing import LabelEncoder
lbl=LabelEncoder()
df=df.apply(lambda x: lbl.fit_transform(x) if x.dtype=='object' else x)
df
# Out:
#      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0          90  2014           3.35           5.59       27000          2
# 1          93  2013           4.75           9.54       43000          1
# 2          68  2017           7.25           9.85        6900          2
# 3          96  2011           2.85           4.15        5200          2
# 4          92  2014           4.60           6.87       42450          1
# ..        ...   ...            ...            ...         ...        ...
# 296        69  2016           9.50          11.60       33988          1
# 297        66  2015           4.00           5.90       60000          2
# 298        69  2009           3.35          11.00       87934          2
# 299        69  2017          11.50          12.50        9000          1
# 300        66  2016           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner
# 0              0             1      0
# ...

# %%
# Correlation Matrix (relationship between various columns)
df.corr()
# Out:
#                Car_Name      Year  Selling_Price  Present_Price  Kms_Driven  \
# Car_Name       1.000000  0.017265       0.499198       0.475539    0.064453
# Year           0.017265  1.000000       0.236141      -0.047584   -0.524342
# Selling_Price  0.499198  0.236141       1.000000       0.878983    0.029187
# Present_Price  0.475539 -0.047584       0.878983       1.000000    0.203647
# Kms_Driven     0.064453 -0.524342       0.029187       0.203647    1.000000
# Fuel_Type     -0.371446 -0.053643      -0.509467      -0.440415   -0.166801
# Seller_Type   -0.829718 -0.039896      -0.550724      -0.512030   -0.101419
# Transmission  -0.059855  0.000394      -0.367128      -0.348715   -0.162510
# Owner         -0.081192 -0.182104      -0.088344       0.008057    0.089216
#
#                Fuel_Type  Seller_Type  Transmission     Owner
# Car_Name       -0.371446    -0.829718     -0.059855 -0.081192
# Year           -0.053643    -0.039896      0.000394 -0.182104
# ...

# %%
# Visualize the Data
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Dependent Variable
dependent=['Year','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']
x=df[dependent]

# OR

x=df.drop(['Car_Name','Selling_Price'],axis=1)
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          2            0             1
# 1    2013           9.54       43000          1            0             1
# 2    2017           9.85        6900          2            0             1
# 3    2011           4.15        5200          2            0             1
# 4    2014           6.87       42450          1            0             1
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             1
# 297  2015           5.90       60000          2            0             1
# 298  2009          11.00       87934          2            0             1
# 299  2017          12.50        9000          1            0             1
# 300  2016           5.90        5464          2            0             1
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# # Linear Regression

# %%
# Splitting the dataset into training and testing data
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
# Model Training
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# Prediction on training data
ytrainpred=model.predict(xtrain)

# %%
from sklearn import metrics
train_error=metrics.r2_score(ytrain,ytrainpred)
print("Score:",train_error*100,'%')
# Out:
# Score: 88.38169193709795 %

# %%
import matplotlib.pyplot as plt
plt.scatter(ytrain,ytrainpred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.show()

# %%
# Prediction on testing data
ytestpred=model.predict(xtest)
test_error=metrics.r2_score(ytest,ytestpred)
print("Score:",test_error*100,'%')
# Out:
# Score: 84.01532365378516 %

# %%
plt.scatter(ytest,ytestpred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.show()

# %%
# Plotting
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.scatter(ytest,ypred,color='g',marker='*',alpha=0.5)
plt.subplot(1,2,2)
plt.plot(xtest,ytest,'o-r')
plt.plot(xtest,ypred,'*-b')
plt.show()

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso 
lassomodel=Lasso()
lassomodel.fit(xtrain,ytrain)
# Out:
# Lasso()

# %%
# Prediction on training data
ytrainpred=lassomodel.predict(xtrain)
train_error=metrics.r2_score(ytrain,ytrainpred)
print("Score:",train_error*100,'%')
plt.scatter(ytrain,ytrainpred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.show()
# Out:
# Score: 84.3587395258283 %

# %%
# Prediction on testing data
ytestpred=lassomodel.predict(xtest)
test_error=metrics.r2_score(ytest,ytestpred)
print("Score:",test_error*100,'%')
plt.scatter(ytest,ytestpred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.show()
# Out:
# Score: 84.9745757073854 %
